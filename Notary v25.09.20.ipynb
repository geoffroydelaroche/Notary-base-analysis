# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Notary-Register-for-RealEstate-Transactions" data-toc-modified-id="Notary-Register-for-RealEstate-Transactions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Notary Register for RealEstate Transactions</a></span></li><li><span><a href="#Import-from-CSV-file" data-toc-modified-id="Import-from-CSV-file-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import from CSV file</a></span></li><li><span><a href="#Import-JSON-file-from-the-API" data-toc-modified-id="Import-JSON-file-from-the-API-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Import JSON file from the API</a></span></li><li><span><a href="#Original-DataBase-analysis" data-toc-modified-id="Original-DataBase-analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Original DataBase analysis</a></span></li><li><span><a href="#Cleaning-columns" data-toc-modified-id="Cleaning-columns-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Cleaning columns</a></span></li><li><span><a href="#Checking-the-values-for-the-column-'type_local'" data-toc-modified-id="Checking-the-values-for-the-column-'type_local'-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Checking the values for the column 'type_local'</a></span></li><li><span><a href="#Saving-Expropriation-DB-for-future-comparaison" data-toc-modified-id="Saving-Expropriation-DB-for-future-comparaison-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Saving Expropriation DB for future comparaison</a></span></li><li><span><a href="#Removing-not-required-or-usable-Rows" data-toc-modified-id="Removing-not-required-or-usable-Rows-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Removing not required or usable Rows</a></span></li></ul></div>

# %% [markdown]
# # Notary Register for RealEstate Transactions

# %%
from IPython.display import Image

# %%
Image(url='http://www.casagrande-labrousse-notaires.com/wp-content/uploads/2016/11/notaire-paris-rue-lincoln-zoom.png')
# Out:
# <img src="http://www.casagrande-labrousse-notaires.com/wp-content/uploads/2016/11/notaire-paris-rue-lincoln-zoom.png"/>

# %%
Image(url='https://de.academic.ru/pictures/dewiki/80/Paris_9th.png')
# Out:
# <img src="https://de.academic.ru/pictures/dewiki/80/Paris_9th.png"/>

# %%
import pandas as pd
import numpy as np
import json
from string import ascii_uppercase
import itertools
import requests as r
from scipy import stats

# %% [markdown]
# # Import JSON file from the API

# %%
# function to genere URL for all (fr AA to BF) for the commune 75109 - Paris 9e
lst=[]
def iter_all_strings():
    for size in itertools.count(1):
        for s in itertools.product(ascii_uppercase, repeat=size):
            yield "".join(s)
for s in iter_all_strings():
    if len(s)<2:
        pass
    else:
        lst.append(s)
    if s == 'BF':
        break
print(lst)
# Out:
# ['AA', 'AB', 'AC', 'AD', 'AE', 'AF', 'AG', 'AH', 'AI', 'AJ', 'AK', 'AL', 'AM', 'AN', 'AO', 'AP', 'AQ', 'AR', 'AS', 'AT', 'AU', 'AV', 'AW', 'AX', 'AY', 'AZ', 'BA', 'BB', 'BC', 'BD', 'BE', 'BF']

# %%
# loop to import all section (fr AA to BF) from the commune 75109 - Paris 9e
lst_df=[]
for i in lst:
    data=r.get(f'https://app.dvf.etalab.gouv.fr/api/mutations3/75109/000{i}')
    data=data.json()
    df = pd.DataFrame(data['mutations'])
    lst_df.append(df) 
db=pd.concat(lst_df, axis=0, ignore_index=True)

# %%
#checking all data info/types, we can see if we use the API to get automatically all the reuqired data.
#we will have some work to update the columns data types to be able to perform analysis. 
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13938 entries, 0 to 13937
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_mutation                   13938 non-null  object
#  1   date_mutation                 13938 non-null  object
#  2   numero_disposition            13938 non-null  object
#  3   nature_mutation               13938 non-null  object
#  4   valeur_fonciere               13938 non-null  object
#  5   adresse_numero                13938 non-null  object
#  6   adresse_suffixe               13938 non-null  object
#  7   adresse_nom_voie              13938 non-null  object
#  8   adresse_code_voie             13938 non-null  object
#  9   code_postal                   13938 non-null  object
#  10  code_commune                  13938 non-null  object
#  11  nom_commune                   13938 non-null  object
#  12  code_departement              13938 non-null  object
#  13  ancien_code_commune           13938 non-null  object
#  14  ancien_nom_commune            13938 non-null  object
#  15  id_parcelle                   13938 non-null  object
#  16  ancien_id_parcelle            13938 non-null  object
#  17  numero_volume                 13938 non-null  object
#  18  lot1_numero                   13938 non-null  object
#  19  lot1_surface_carrez           13938 non-null  object
#  20  lot2_numero                   13938 non-null  object
#  21  lot2_surface_carrez           13938 non-null  object
#  22  lot3_numero                   13938 non-null  object
#  23  lot3_surface_carrez           13938 non-null  object
#  24  lot4_numero                   13938 non-null  object
#  25  lot4_surface_carrez           13938 non-null  object
#  26  lot5_numero                   13938 non-null  object
#  27  lot5_surface_carrez           13938 non-null  object
#  28  nombre_lots                   13938 non-null  object
#  29  code_type_local               13938 non-null  object
#  30  type_local                    13938 non-null  object
#  31  surface_reelle_bati           13938 non-null  object
#  32  nombre_pieces_principales     13938 non-null  object
#  33  code_nature_culture           13938 non-null  object
#  34  nature_culture                13938 non-null  object
#  35  code_nature_culture_speciale  13938 non-null  object
#  36  nature_culture_speciale       13938 non-null  object
#  37  surface_terrain               13938 non-null  object
#  38  longitude                     13938 non-null  object
#  39  latitude                      13938 non-null  object
#  40  section_prefixe               13938 non-null  object
# dtypes: object(41)
# memory usage: 4.4+ MB

# %% [markdown]
# # Original DataBase analysis

# %%
#checking unique values for columns with data not clear for us

# %%
db['type_local'].unique()
# Out:
# array(['Appartement', 'Local industriel. commercial ou assimilé',
#        'Dépendance', 'Maison', 'None'], dtype=object)

# %%
db['numero_disposition'].unique()
# can be remove
# Out:
# array(['1', '2', '13', '14', '15', '16', '17', '18', '23', '4', '3', '19',
#        '20', '21', '22', '24', '5'], dtype=object)

# %%
db['code_type_local'].unique()
# can be remove
# Out:
# array(['2', '4', '3', '1', 'None'], dtype=object)

# %%
db['code_nature_culture'].unique()
# can be remove
# Out:
# array(['None', 'S', 'AG'], dtype=object)

# %%
db['nature_culture'].unique()
# can be remove
# Out:
# array(['None', 'sols', "terrains d'agrément"], dtype=object)

# %%
db['code_nature_culture_speciale'].unique()
# can be remove
# Out:
# array(['None'], dtype=object)

# %%
db['nature_culture_speciale'].unique()
# can be remove
# Out:
# array(['None'], dtype=object)

# %%
# checking all rows where the 'type_local' is none. 
# Meaning not defined as 'Appartement', 'Local industriel. commercial ou assimilé','Dépendance', 'Maison'
db.loc[db['type_local'] == 'None']
# Out:
#         id_mutation date_mutation numero_disposition  \
# 591    2014-1061534    2014-07-15                  1
# 640    2019-1072261    2019-11-15                  1
# 686    2019-1071056    2019-07-12                  1
# 708    2019-1070255    2019-05-13                  1
# 709    2019-1070127    2019-05-03                  1
# ...             ...           ...                ...
# 8824   2017-1408700    2017-06-30                  2
# 8894   2016-1240081    2016-04-07                  1
# 10899  2019-1068960    2019-01-23                  1
# 10910  2018-1375831    2018-12-13                  1
# 11403  2019-1069408    2019-03-01                  1
#
#                           nature_mutation valeur_fonciere adresse_numero  \
# 591                                 Vente          6000.0             12
# 640    Vente en l'état futur d'achèvement         45000.0           50.0
# 686    Vente en l'état futur d'achèvement         65000.0           50.0
# 708    Vente en l'état futur d'achèvement         37000.0           50.0
# 709    Vente en l'état futur d'achèvement       1800000.0           50.0
# ...                                   ...             ...            ...
# 8824                                Vente       7035000.0            nan
# 8894                                Vente       2945000.0            nan
# 10899  Vente en l'état futur d'achèvement     148977600.0             39
# 10910                               Vente       5598626.0              1
# 11403                               Vente       2000000.0             12
#
#       adresse_suffixe      adresse_nom_voie adresse_code_voie code_postal  \
# 591              None         RUE DE CALAIS              1434       75009
# 640              None         RUE DE CLICHY              2116       75009
# 686              None         RUE DE CLICHY              2116       75009
# 708              None         RUE DE CLICHY              2116       75009
# 709              None         RUE DE CLICHY              2116       75009
# ...               ...                   ...               ...         ...
# 8824             None                  None              None        None
# 8894             None                  None              None        None
# 10899            None           AV TRUDAINE              9484       75009
# 10910            None  RUE BOCHART DE SARON              1046       75009
# 11403               A          RUE DU DELTA              2685       75009
#
#        ... surface_reelle_bati nombre_pieces_principales code_nature_culture  \
# 591    ...                 nan                       nan                   S
# 640    ...                 nan                       nan                None
# 686    ...                 nan                       nan                None
# 708    ...                 nan                       nan                None
# 709    ...                 nan                       nan                None
# ...    ...                 ...                       ...                 ...
# 8824   ...                 nan                       nan                None
# 8894   ...                 nan                       nan                None
# 10899  ...                 nan                       nan                None
# 10910  ...                 nan                       nan                None
# 11403  ...                 nan                       nan                  AG
#
#             nature_culture code_nature_culture_speciale  \
# 591                   sols                         None
# 640                   None                         None
# 686                   None                         None
# 708                   None                         None
# 709                   None                         None
# ...                    ...                          ...
# 8824                  None                         None
# 8894                  None                         None
# 10899                 None                         None
# 10910                 None                         None
# 11403  terrains d'agrément                         None
#
#       nature_culture_speciale surface_terrain longitude   latitude  \
# 591                      None           264.0  2.331055  48.882679
# 640                      None             nan  2.329696  48.880336
# 686                      None             nan  2.329696  48.880336
# 708                      None             nan  2.329696  48.880336
# 709                      None             nan  2.329696  48.880336
# ...                       ...             ...       ...        ...
# 8824                     None             nan  2.338943  48.874948
# 8894                     None             nan   2.34329  48.875568
# 10899                    None             nan  2.342295  48.880777
# 10910                    None             nan  2.342295  48.880777
# 11403                    None            10.0  2.348269  48.882925
#
#       section_prefixe
# 591             000AA
# 640             000AB
# 686             000AB
# 708             000AB
# 709             000AB
# ...               ...
# 8824            000AY
# 8894            000AY
# 10899           000BB
# 10910           000BB
# 11403           000BC
#
# [243 rows x 41 columns]

# %%
# checking 'nature_mutation' for all ['type_local'] == 'None'
chk1 = db.loc[db['type_local'] == 'None']
chk1['nature_mutation'].unique()
# Out:
# array(['Vente', "Vente en l'état futur d'achèvement", 'Expropriation',
#        'Echange'], dtype=object)

# %%
# checking expropriation is that bucket
db.loc[(db['type_local'] == 'None') & (db['nature_mutation'] == 'Expropriation')]
# Out:
#        id_mutation date_mutation numero_disposition nature_mutation  \
# 1250  2014-1063066    2014-05-13                 13   Expropriation
# 1251  2014-1063067    2014-05-13                 14   Expropriation
# 1252  2014-1063068    2014-05-13                 15   Expropriation
# 1253  2014-1063069    2014-05-13                 16   Expropriation
# 1254  2014-1063070    2014-05-13                 17   Expropriation
# 1255  2014-1063071    2014-05-13                 18   Expropriation
# 1256  2014-1063076    2014-05-13                 23   Expropriation
# 5005  2014-1063072    2014-05-13                 19   Expropriation
# 5006  2014-1063073    2014-05-13                 20   Expropriation
# 5007  2014-1063074    2014-05-13                 21   Expropriation
# 5008  2014-1063075    2014-05-13                 22   Expropriation
# 5009  2014-1063077    2014-05-13                 24   Expropriation
#
#      valeur_fonciere adresse_numero adresse_suffixe adresse_nom_voie  \
# 1250         37272.0           74.0            None  RUE D AMSTERDAM
# 1251         61064.0           72.0            None  RUE D AMSTERDAM
# 1252        166758.0           70.0            None  RUE D AMSTERDAM
# 1253        176698.0           66.0            None  RUE D AMSTERDAM
# 1254         84469.0           60.0            None  RUE D AMSTERDAM
# 1255        203125.0           16.0            None     RUE DE LIEGE
# 1256          7678.0           76.0            None  RUE D AMSTERDAM
# 5005         58233.0           15.0            None     RUE DE LIEGE
# 5006        173460.0           17.0            None     RUE DE LIEGE
# 5007          8747.0           54.0            None  RUE D AMSTERDAM
# 5008        202398.0           50.0            None  RUE D AMSTERDAM
# 5009        146813.0           48.0            None  RUE D AMSTERDAM
#
#      adresse_code_voie code_postal  ... surface_reelle_bati  \
# 1250              0300       75009  ...                 nan
# 1251              0300       75009  ...                 nan
# 1252              0300       75009  ...                 nan
# 1253              0300       75009  ...                 nan
# 1254              0300       75009  ...                 nan
# 1255              5665       75009  ...                 nan
# 1256              0300       75009  ...                 nan
# 5005              5665       75009  ...                 nan
# 5006              5665       75009  ...                 nan
# 5007              0300       75009  ...                 nan
# 5008              0300       75009  ...                 nan
# 5009              0300       75009  ...                 nan
#
#      nombre_pieces_principales code_nature_culture nature_culture  \
# 1250                       nan                None           None
# 1251                       nan                None           None
# 1252                       nan                None           None
# 1253                       nan                None           None
# 1254                       nan                None           None
# 1255                       nan                None           None
# 1256                       nan                None           None
# 5005                       nan                None           None
# 5006                       nan                None           None
# 5007                       nan                None           None
# 5008                       nan                None           None
# 5009                       nan                None           None
#
#      code_nature_culture_speciale nature_culture_speciale surface_terrain  \
# 1250                         None                    None             nan
# 1251                         None                    None             nan
# 1252                         None                    None             nan
# 1253                         None                    None             nan
# 1254                         None                    None             nan
# 1255                         None                    None             nan
# 1256                         None                    None             nan
# 5005                         None                    None             nan
# 5006                         None                    None             nan
# 5007                         None                    None             nan
# 5008                         None                    None             nan
# 5009                         None                    None             nan
#
#      longitude   latitude section_prefixe
# 1250  2.327401  48.880914           000AB
# 1251  2.327398  48.880848           000AB
# 1252  2.327532  48.880619           000AB
# 1253  2.327518  48.880197           000AB
# 1254   2.32734  48.879891           000AB
# 1255  2.327489  48.879966           000AB
# 1256  2.327416  48.881063           000AB
# 5005  2.327569  48.879393           000AJ
# 5006  2.327299   48.87941           000AJ
# 5007  2.327215   48.87934           000AJ
# 5008  2.327475  48.879046           000AJ
# 5009  2.327295  48.878874           000AJ
#
# [12 rows x 41 columns]

# %%
# checking expropriation is the entire db to compare
db.loc[db['nature_mutation'] == 'Expropriation']
# Out:
#        id_mutation date_mutation numero_disposition nature_mutation  \
# 1250  2014-1063066    2014-05-13                 13   Expropriation
# 1251  2014-1063067    2014-05-13                 14   Expropriation
# 1252  2014-1063068    2014-05-13                 15   Expropriation
# 1253  2014-1063069    2014-05-13                 16   Expropriation
# 1254  2014-1063070    2014-05-13                 17   Expropriation
# 1255  2014-1063071    2014-05-13                 18   Expropriation
# 1256  2014-1063076    2014-05-13                 23   Expropriation
# 5005  2014-1063072    2014-05-13                 19   Expropriation
# 5006  2014-1063073    2014-05-13                 20   Expropriation
# 5007  2014-1063074    2014-05-13                 21   Expropriation
# 5008  2014-1063075    2014-05-13                 22   Expropriation
# 5009  2014-1063077    2014-05-13                 24   Expropriation
#
#      valeur_fonciere adresse_numero adresse_suffixe adresse_nom_voie  \
# 1250         37272.0           74.0            None  RUE D AMSTERDAM
# 1251         61064.0           72.0            None  RUE D AMSTERDAM
# 1252        166758.0           70.0            None  RUE D AMSTERDAM
# 1253        176698.0           66.0            None  RUE D AMSTERDAM
# 1254         84469.0           60.0            None  RUE D AMSTERDAM
# 1255        203125.0           16.0            None     RUE DE LIEGE
# 1256          7678.0           76.0            None  RUE D AMSTERDAM
# 5005         58233.0           15.0            None     RUE DE LIEGE
# 5006        173460.0           17.0            None     RUE DE LIEGE
# 5007          8747.0           54.0            None  RUE D AMSTERDAM
# 5008        202398.0           50.0            None  RUE D AMSTERDAM
# 5009        146813.0           48.0            None  RUE D AMSTERDAM
#
#      adresse_code_voie code_postal  ... surface_reelle_bati  \
# 1250              0300       75009  ...                 nan
# 1251              0300       75009  ...                 nan
# 1252              0300       75009  ...                 nan
# 1253              0300       75009  ...                 nan
# 1254              0300       75009  ...                 nan
# 1255              5665       75009  ...                 nan
# 1256              0300       75009  ...                 nan
# 5005              5665       75009  ...                 nan
# 5006              5665       75009  ...                 nan
# 5007              0300       75009  ...                 nan
# 5008              0300       75009  ...                 nan
# 5009              0300       75009  ...                 nan
#
#      nombre_pieces_principales code_nature_culture nature_culture  \
# 1250                       nan                None           None
# 1251                       nan                None           None
# 1252                       nan                None           None
# 1253                       nan                None           None
# 1254                       nan                None           None
# 1255                       nan                None           None
# 1256                       nan                None           None
# 5005                       nan                None           None
# 5006                       nan                None           None
# 5007                       nan                None           None
# 5008                       nan                None           None
# 5009                       nan                None           None
#
#      code_nature_culture_speciale nature_culture_speciale surface_terrain  \
# 1250                         None                    None             nan
# 1251                         None                    None             nan
# 1252                         None                    None             nan
# 1253                         None                    None             nan
# 1254                         None                    None             nan
# 1255                         None                    None             nan
# 1256                         None                    None             nan
# 5005                         None                    None             nan
# 5006                         None                    None             nan
# 5007                         None                    None             nan
# 5008                         None                    None             nan
# 5009                         None                    None             nan
#
#      longitude   latitude section_prefixe
# 1250  2.327401  48.880914           000AB
# 1251  2.327398  48.880848           000AB
# 1252  2.327532  48.880619           000AB
# 1253  2.327518  48.880197           000AB
# 1254   2.32734  48.879891           000AB
# 1255  2.327489  48.879966           000AB
# 1256  2.327416  48.881063           000AB
# 5005  2.327569  48.879393           000AJ
# 5006  2.327299   48.87941           000AJ
# 5007  2.327215   48.87934           000AJ
# 5008  2.327475  48.879046           000AJ
# 5009  2.327295  48.878874           000AJ
#
# [12 rows x 41 columns]

# %%
# we can see here 200 transactions are VEFA, meaning NEW FLATS
db.loc[db['nature_mutation'] == 'Vente en l\'état futur d\'achèvement']
# Out:
#         id_mutation date_mutation numero_disposition  \
# 640    2019-1072261    2019-11-15                  1
# 686    2019-1071056    2019-07-12                  1
# 708    2019-1070255    2019-05-13                  1
# 709    2019-1070127    2019-05-03                  1
# 710    2019-1070127    2019-05-03                  1
# ...             ...           ...                ...
# 7445   2017-1410320    2017-11-16                  2
# 7446   2017-1410320    2017-11-16                  2
# 7447   2017-1410320    2017-11-16                  2
# 7448   2017-1410320    2017-11-16                  2
# 10899  2019-1068960    2019-01-23                  1
#
#                           nature_mutation valeur_fonciere adresse_numero  \
# 640    Vente en l'état futur d'achèvement         45000.0           50.0
# 686    Vente en l'état futur d'achèvement         65000.0           50.0
# 708    Vente en l'état futur d'achèvement         37000.0           50.0
# 709    Vente en l'état futur d'achèvement       1800000.0           50.0
# 710    Vente en l'état futur d'achèvement       1800000.0           50.0
# ...                                   ...             ...            ...
# 7445   Vente en l'état futur d'achèvement      17593000.0              7
# 7446   Vente en l'état futur d'achèvement      17593000.0              7
# 7447   Vente en l'état futur d'achèvement      17593000.0              7
# 7448   Vente en l'état futur d'achèvement      17593000.0              7
# 10899  Vente en l'état futur d'achèvement     148977600.0             39
#
#       adresse_suffixe adresse_nom_voie adresse_code_voie code_postal  ...  \
# 640              None    RUE DE CLICHY              2116       75009  ...
# 686              None    RUE DE CLICHY              2116       75009  ...
# 708              None    RUE DE CLICHY              2116       75009  ...
# 709              None    RUE DE CLICHY              2116       75009  ...
# 710              None    RUE DE CLICHY              2116       75009  ...
# ...               ...              ...               ...         ...  ...
# 7445             None      RUE BERGERE              0888       75009  ...
# 7446             None      RUE BERGERE              0888       75009  ...
# 7447             None      RUE BERGERE              0888       75009  ...
# 7448             None      RUE BERGERE              0888       75009  ...
# 10899            None      AV TRUDAINE              9484       75009  ...
#
#       surface_reelle_bati nombre_pieces_principales code_nature_culture  \
# 640                   nan                       nan                None
# 686                   nan                       nan                None
# 708                   nan                       nan                None
# 709                   nan                       nan                None
# 710                   nan                       nan                None
# ...                   ...                       ...                 ...
# 7445                 73.0                       0.0                None
# 7446                 13.0                       0.0                None
# 7447                 13.0                       0.0                None
# 7448                 11.0                       0.0                None
# 10899                 nan                       nan                None
#
#       nature_culture code_nature_culture_speciale nature_culture_speciale  \
# 640             None                         None                    None
# 686             None                         None                    None
# 708             None                         None                    None
# 709             None                         None                    None
# 710             None                         None                    None
# ...              ...                          ...                     ...
# 7445            None                         None                    None
# 7446            None                         None                    None
# 7447            None                         None                    None
# 7448            None                         None                    None
# 10899           None                         None                    None
#
#       surface_terrain longitude   latitude section_prefixe
# 640               nan  2.329696  48.880336           000AB
# 686               nan  2.329696  48.880336           000AB
# 708               nan  2.329696  48.880336           000AB
# 709               nan  2.329696  48.880336           000AB
# 710               nan  2.329696  48.880336           000AB
# ...               ...       ...        ...             ...
# 7445              nan  2.346854  48.871892           000AV
# 7446              nan  2.346854  48.871892           000AV
# 7447              nan  2.346854  48.871892           000AV
# 7448              nan  2.346854  48.871892           000AV
# 10899             nan  2.342295  48.880777           000BB
#
# [200 rows x 41 columns]

# %%
chk2 = db.loc[db['nature_mutation'] == 'Vente en l\'état futur d\'achèvement']
chk2['type_local'].unique()
# Out:
# array(['None', 'Appartement', 'Local industriel. commercial ou assimilé'],
#       dtype=object)

# %%
# checking number of transaction VEFA without any label for ['type_local']
db.loc[(db['nature_mutation'] == 'Vente en l\'état futur d\'achèvement') & (db['type_local'] == 'None' )].sample(5)
# Out:
#        id_mutation date_mutation numero_disposition  \
# 1022  2017-1408463    2017-06-26                  1
# 879   2018-1372316    2018-01-08                  1
# 985   2017-1409281    2017-08-22                  1
# 1010  2017-1408987    2017-07-10                  1
# 1038  2017-1407953    2017-04-20                  1
#
#                          nature_mutation valeur_fonciere adresse_numero  \
# 1022  Vente en l'état futur d'achèvement       1390000.0           50.0
# 879   Vente en l'état futur d'achèvement        929000.0           50.0
# 985   Vente en l'état futur d'achèvement        471000.0           50.0
# 1010  Vente en l'état futur d'achèvement       1697000.0           50.0
# 1038  Vente en l'état futur d'achèvement        558000.0            nan
#
#      adresse_suffixe adresse_nom_voie adresse_code_voie code_postal  ...  \
# 1022            None    RUE DE CLICHY              2116       75009  ...
# 879             None    RUE DE CLICHY              2116       75009  ...
# 985             None    RUE DE CLICHY              2116       75009  ...
# 1010            None    RUE DE CLICHY              2116       75009  ...
# 1038            None             None              None        None  ...
#
#      surface_reelle_bati nombre_pieces_principales code_nature_culture  \
# 1022                 nan                       nan                None
# 879                  nan                       nan                None
# 985                  nan                       nan                None
# 1010                 nan                       nan                None
# 1038                 nan                       nan                None
#
#      nature_culture code_nature_culture_speciale nature_culture_speciale  \
# 1022           None                         None                    None
# 879            None                         None                    None
# 985            None                         None                    None
# 1010           None                         None                    None
# 1038           None                         None                    None
#
#      surface_terrain longitude   latitude section_prefixe
# 1022             nan  2.329696  48.880336           000AB
# 879              nan  2.329696  48.880336           000AB
# 985              nan  2.329696  48.880336           000AB
# 1010             nan  2.329696  48.880336           000AB
# 1038             nan  2.329696  48.880336           000AB
#
# [5 rows x 41 columns]

# %%
#checking different operations
chk3 = db.loc[(db['nature_mutation'] == 'Vente en l\'état futur d\'achèvement') & (db['type_local'] == 'None' )]
chk3['longitude'].unique()
# Out:
# array(['2.329696', '2.342295'], dtype=object)

# %%
#checking different operations
chk3 = db.loc[(db['nature_mutation'] == 'Vente en l\'état futur d\'achèvement') & (db['type_local'] == 'None' )]
chk3['latitude'].unique()
# Out:
# array(['48.880336', '48.880777'], dtype=object)

# %%
#with that check we can see the VEFA transactions come from 2 new operation in the area

# %%
chk3[['lot1_surface_carrez',
      'lot2_surface_carrez',
      'lot3_surface_carrez',
      'lot4_surface_carrez',
      'lot5_surface_carrez',
      'surface_reelle_bati',
      'nombre_pieces_principales',
      'surface_terrain']]
# Out:
#       lot1_surface_carrez lot2_surface_carrez lot3_surface_carrez  \
# 640                   nan                 nan                 nan
# 686                   nan                 nan                 nan
# 708                   nan                 nan                 nan
# 709                   nan                 nan                 nan
# 710                   nan                 nan                 nan
# ...                   ...                 ...                 ...
# 1038                38.65                 nan                 nan
# 1040                30.44                 nan                 nan
# 1041                23.51                 nan                 nan
# 1042                  nan                 nan                 nan
# 10899                 nan                 nan                 nan
#
#       lot4_surface_carrez lot5_surface_carrez surface_reelle_bati  \
# 640                   nan                 nan                 nan
# 686                   nan                 nan                 nan
# 708                   nan                 nan                 nan
# 709                   nan                 nan                 nan
# 710                   nan                 nan                 nan
# ...                   ...                 ...                 ...
# 1038                  nan                 nan                 nan
# 1040                  nan                 nan                 nan
# 1041                  nan                 nan                 nan
# 1042                  nan                 nan                 nan
# 10899                 nan                 nan                 nan
#
#       nombre_pieces_principales surface_terrain
# 640                         nan             nan
# 686                         nan             nan
# 708                         nan             nan
# 709                         nan             nan
# 710                         nan             nan
# ...                         ...             ...
# 1038                        nan             nan
# 1040                        nan             nan
# 1041                        nan             nan
# 1042                        nan             nan
# 10899                       nan             nan
#
# [108 rows x 8 columns]

# %%
#with that check we can see only surface are given into 'lot1_surface_carrez'
#let's apply that logic below (keeping only flats where we have surface and price for none)
chk3[['lot1_surface_carrez',
      'lot2_surface_carrez',
      'lot3_surface_carrez',
      'lot4_surface_carrez',
      'lot5_surface_carrez',
      'surface_reelle_bati',
      'nombre_pieces_principales',
      'surface_terrain']].describe()
# Out:
#        lot1_surface_carrez lot2_surface_carrez lot3_surface_carrez  \
# count                  108                 108                 108
# unique                  12                   1                   1
# top                    nan                 nan                 nan
# freq                    95                 108                 108
#
#        lot4_surface_carrez lot5_surface_carrez surface_reelle_bati  \
# count                  108                 108                 108
# unique                   1                   1                   1
# top                    nan                 nan                 nan
# freq                   108                 108                 108
#
#        nombre_pieces_principales surface_terrain
# count                        108             108
# unique                         1               1
# top                          nan             nan
# freq                         108             108

# %%
chk3.loc[(db['lot1_surface_carrez'] != 'nan')]
# Out:
#        id_mutation date_mutation numero_disposition  \
# 995   2017-1409156    2017-07-26                  1
# 996   2017-1409128    2017-07-24                  1
# 998   2017-1409093    2017-07-19                  1
# 1001  2017-1409063    2017-07-18                  1
# 1002  2017-1409064    2017-07-17                  1
# 1004  2017-1409030    2017-07-12                  1
# 1013  2017-1408928    2017-07-06                  1
# 1023  2017-1408617    2017-06-21                  1
# 1029  2017-1408154    2017-05-09                  1
# 1034  2017-1407963    2017-04-21                  1
# 1038  2017-1407953    2017-04-20                  1
# 1040  2017-1407835    2017-04-06                  1
# 1041  2017-1407665    2017-03-27                  1
#
#                          nature_mutation valeur_fonciere adresse_numero  \
# 995   Vente en l'état futur d'achèvement       1198000.0           50.0
# 996   Vente en l'état futur d'achèvement        377000.0           50.0
# 998   Vente en l'état futur d'achèvement        560000.0           50.0
# 1001  Vente en l'état futur d'achèvement       2323000.0           50.0
# 1002  Vente en l'état futur d'achèvement        343000.0           50.0
# 1004  Vente en l'état futur d'achèvement        866000.0           50.0
# 1013  Vente en l'état futur d'achèvement        283000.0           50.0
# 1023  Vente en l'état futur d'achèvement        473000.0           50.0
# 1029  Vente en l'état futur d'achèvement        390000.0           50.0
# 1034  Vente en l'état futur d'achèvement        916000.0            nan
# 1038  Vente en l'état futur d'achèvement        558000.0            nan
# 1040  Vente en l'état futur d'achèvement        410000.0            nan
# 1041  Vente en l'état futur d'achèvement        273000.0            nan
#
#      adresse_suffixe adresse_nom_voie adresse_code_voie code_postal  ...  \
# 995             None    RUE DE CLICHY              2116       75009  ...
# 996             None    RUE DE CLICHY              2116       75009  ...
# 998             None    RUE DE CLICHY              2116       75009  ...
# 1001            None    RUE DE CLICHY              2116       75009  ...
# 1002            None    RUE DE CLICHY              2116       75009  ...
# 1004            None    RUE DE CLICHY              2116       75009  ...
# 1013            None    RUE DE CLICHY              2116       75009  ...
# 1023            None    RUE DE CLICHY              2116       75009  ...
# 1029            None    RUE DE CLICHY              2116       75009  ...
# 1034            None             None              None        None  ...
# 1038            None             None              None        None  ...
# 1040            None             None              None        None  ...
# 1041            None             None              None        None  ...
#
#      surface_reelle_bati nombre_pieces_principales code_nature_culture  \
# 995                  nan                       nan                None
# 996                  nan                       nan                None
# 998                  nan                       nan                None
# 1001                 nan                       nan                None
# 1002                 nan                       nan                None
# 1004                 nan                       nan                None
# 1013                 nan                       nan                None
# 1023                 nan                       nan                None
# 1029                 nan                       nan                None
# 1034                 nan                       nan                None
# 1038                 nan                       nan                None
# 1040                 nan                       nan                None
# 1041                 nan                       nan                None
#
#      nature_culture code_nature_culture_speciale nature_culture_speciale  \
# 995            None                         None                    None
# 996            None                         None                    None
# 998            None                         None                    None
# 1001           None                         None                    None
# 1002           None                         None                    None
# 1004           None                         None                    None
# 1013           None                         None                    None
# 1023           None                         None                    None
# 1029           None                         None                    None
# 1034           None                         None                    None
# 1038           None                         None                    None
# 1040           None                         None                    None
# 1041           None                         None                    None
#
#      surface_terrain longitude   latitude section_prefixe
# 995              nan  2.329696  48.880336           000AB
# 996              nan  2.329696  48.880336           000AB
# 998              nan  2.329696  48.880336           000AB
# 1001             nan  2.329696  48.880336           000AB
# 1002             nan  2.329696  48.880336           000AB
# 1004             nan  2.329696  48.880336           000AB
# 1013             nan  2.329696  48.880336           000AB
# 1023             nan  2.329696  48.880336           000AB
# 1029             nan  2.329696  48.880336           000AB
# 1034             nan  2.329696  48.880336           000AB
# 1038             nan  2.329696  48.880336           000AB
# 1040             nan  2.329696  48.880336           000AB
# 1041             nan  2.329696  48.880336           000AB
#
# [13 rows x 41 columns]

# %%
#Correlation bwt surface VS price for VEFA flats
chk4 = chk3[['valeur_fonciere','lot1_surface_carrez']]
chk4['valeur_fonciere'] = np.float64(chk4['valeur_fonciere'])
chk4['lot1_surface_carrez'] = np.float64(chk4['lot1_surface_carrez'])
chk4.corr()
# Out:
# <ipython-input-29-3354cf9500c9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chk4['valeur_fonciere'] = np.float64(chk4['valeur_fonciere'])
# <ipython-input-29-3354cf9500c9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chk4['lot1_surface_carrez'] = np.float64(chk4['lot1_surface_carrez'])
#                      valeur_fonciere  lot1_surface_carrez
# valeur_fonciere             1.000000             0.992889
# lot1_surface_carrez         0.992889             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = chk4['valeur_fonciere']
y = chk4['lot1_surface_carrez']

plt.scatter(x,y,c="g", alpha=0.5, marker=r'$\clubsuit$', label='Transactions')

plt.legend()
plt.title('Valeur VS Surface')

plt.xlabel('lot1_surface_carrez')
plt.ylabel('valeur_fonciere')

plt.show() #to stop changes

# %% [markdown]
# # Cleaning columns

# %%
# to convert nan & None to 0
db.iloc[:, 18:28]=db.iloc[:, 18:28].replace('nan', 0)
db.iloc[:, 18:28]=db.iloc[:, 18:28].replace('None', 0)
db['surface_reelle_bati']=db['surface_reelle_bati'].replace('nan', 0)
db['surface_reelle_bati']=db['surface_reelle_bati'].replace('None', 0)

# cleaning columns column 'surface_terrain'
db['surface_terrain']=db['surface_terrain'].replace('nan', 0)
db['surface_terrain']=db['surface_terrain'].replace('None', 0)

# to convert required columns to float64
db['lot1_surface_carrez'] = np.float64(db['lot1_surface_carrez'])
db['lot2_surface_carrez'] = np.float64(db['lot2_surface_carrez'])
db['lot3_surface_carrez'] = np.float64(db['lot3_surface_carrez'])
db['lot4_surface_carrez'] = np.float64(db['lot4_surface_carrez'])
db['lot5_surface_carrez'] = np.float64(db['lot5_surface_carrez'])
db['surface_reelle_bati'] = np.float64(db['surface_reelle_bati'])
db['valeur_fonciere'] = np.float64(db['valeur_fonciere'])
db['surface_terrain'] = np.float64(db['surface_terrain'])
db['longitude'] = np.float64(db['longitude'])
db['latitude'] = np.float64(db['latitude'])

# simplification of the parcelle number (we might need to remove that line based on other linked data)
# possible key value
db['id_parcelle']=db['id_parcelle'].str[-4:]

# cleaning columns 'nombre_pieces_principales'
db['nombre_pieces_principales'].unique()
db['nombre_pieces_principales']=db['nombre_pieces_principales'].replace('nan', 0)
db['nombre_pieces_principales']=db['nombre_pieces_principales'].astype(np.float64)
db['nombre_pieces_principales']=db['nombre_pieces_principales'].astype(np.int64)

# adding new colum for the sum & compare to 'surface_reelle_bati'
db['surface_carrez_total']=db['lot1_surface_carrez']+db['lot2_surface_carrez']+db['lot3_surface_carrez']+db['lot4_surface_carrez']+db['lot5_surface_carrez']

# %%
columns_d = ['numero_disposition',
         'code_departement',
         'ancien_code_commune',
         'ancien_nom_commune',
         'ancien_id_parcelle',
         'numero_volume',
         'lot1_numero',
         'lot1_surface_carrez',
         'lot2_numero',
         'lot2_surface_carrez',
         'lot3_numero',
         'lot3_surface_carrez',
         'lot4_numero',
         'lot4_surface_carrez',
         'lot5_numero',
         'lot5_surface_carrez',
         'nombre_lots',
         'code_type_local',
         'code_nature_culture',
         'nature_culture',
         'code_nature_culture_speciale',
         'nature_culture_speciale']

db=db.drop(columns=columns_d)
db
# Out:
#         id_mutation date_mutation nature_mutation  valeur_fonciere  \
# 0      2019-1072649    2019-12-23           Vente         665000.0
# 1      2019-1072739    2019-12-19           Vente       18300000.0
# 2      2019-1072673    2019-12-16           Vente          71000.0
# 3      2019-1072512    2019-12-13           Vente        1520000.0
# 4      2019-1072512    2019-12-13           Vente        1520000.0
# ...             ...           ...             ...              ...
# 13933  2014-1059819    2014-01-13           Vente         252000.0
# 13934  2014-1059714    2014-01-10           Vente         540000.0
# 13935  2014-1059717    2014-01-10           Vente         102000.0
# 13936  2014-1059717    2014-01-10           Vente         102000.0
# 13937  2014-1059709    2014-01-09           Vente         443000.0
#
#       adresse_numero adresse_suffixe     adresse_nom_voie adresse_code_voie  \
# 0                 47            None         RUE DE DOUAI              2909
# 1                106            None      RUE D AMSTERDAM              0300
# 2                 14            None            RUE BALLU              0646
# 3                  1            None       PL ADOLPHE MAX              0065
# 4                  1            None       PL ADOLPHE MAX              0065
# ...              ...             ...                  ...               ...
# 13933             10            None  RUE DE ROCHECHOUART              8289
# 13934             10            None           RUE MAYRAN              6223
# 13935              4            None       RUE ROCHAMBEAU              8283
# 13936              4            None       RUE ROCHAMBEAU              8283
# 13937             29            None     RUE DE BELLEFOND              0827
#
#       code_postal code_commune              nom_commune id_parcelle  \
# 0           75009        75109  Paris 9e Arrondissement        0044
# 1           75009        75109  Paris 9e Arrondissement        0119
# 2           75009        75109  Paris 9e Arrondissement        0065
# 3           75009        75109  Paris 9e Arrondissement        0040
# 4           75009        75109  Paris 9e Arrondissement        0040
# ...           ...          ...                      ...         ...
# 13933       75009        75109  Paris 9e Arrondissement        0067
# 13934       75009        75109  Paris 9e Arrondissement        0009
# 13935       75009        75109  Paris 9e Arrondissement        0024
# 13936       75009        75109  Paris 9e Arrondissement        0024
# 13937       75009        75109  Paris 9e Arrondissement        0018
#
#                                      type_local  surface_reelle_bati  \
# 0                                   Appartement                 55.0
# 1      Local industriel. commercial ou assimilé                693.0
# 2                                    Dépendance                  0.0
# 3                                   Appartement                123.0
# 4                                   Appartement                  6.0
# ...                                         ...                  ...
# 13933                               Appartement                 25.0
# 13934                               Appartement                 60.0
# 13935                                Dépendance                  0.0
# 13936                                Dépendance                  0.0
# 13937                               Appartement                 43.0
#
#        nombre_pieces_principales  surface_terrain  longitude   latitude  \
# 0                              4              0.0   2.330953  48.882913
# 1                              0              0.0   2.327339  48.883026
# 2                              0              0.0   2.330517  48.882159
# 3                              5              0.0   2.330485  48.883136
# 4                              1              0.0   2.330485  48.883136
# ...                          ...              ...        ...        ...
# 13933                          1              0.0   2.345008  48.877038
# 13934                          3              0.0   2.344981  48.877407
# 13935                          0              0.0   2.346670  48.877538
# 13936                          0              0.0   2.346670  48.877538
# 13937                          3              0.0   2.346413  48.877644
#
#       section_prefixe  surface_carrez_total
# 0               000AA                 57.40
# 1               000AA                  0.00
# 2               000AA                  0.00
# 3               000AA                125.75
# 4               000AA                  5.57
# ...               ...                   ...
# 13933           000BF                  0.00
# 13934           000BF                 59.75
# 13935           000BF                  0.00
# 13936           000BF                  0.00
# 13937           000BF                  0.00
#
# [13938 rows x 20 columns]

# %%
db.dtypes
# Out:
# id_mutation                   object
# date_mutation                 object
# nature_mutation               object
# valeur_fonciere              float64
# adresse_numero                object
# adresse_suffixe               object
# adresse_nom_voie              object
# adresse_code_voie             object
# code_postal                   object
# code_commune                  object
# nom_commune                   object
# id_parcelle                   object
# type_local                    object
# surface_reelle_bati          float64
# nombre_pieces_principales      int64
# surface_terrain              float64
# longitude                    float64
# latitude                     float64
# section_prefixe               object
# surface_carrez_total         float64
# dtype: object

# %%
#comparing surface relle & surface Carrez total
db[['nature_mutation','valeur_fonciere','surface_reelle_bati','surface_carrez_total','type_local']].sample(10)
# Out:
#       nature_mutation  valeur_fonciere  surface_reelle_bati  \
# 8683            Vente         555000.0                 48.0
# 10863           Vente         250000.0                 53.0
# 459             Vente         810000.0                  0.0
# 6313            Vente              1.2                  0.0
# 7727            Vente         133000.0                 15.0
# 6256            Vente         357700.0                 27.0
# 268             Vente          30000.0                  0.0
# 3746            Vente          84700.0                  0.0
# 248             Vente         663462.0                349.0
# 8823            Vente        1495000.0                136.0
#
#        surface_carrez_total                                type_local
# 8683                  48.12                               Appartement
# 10863                  0.00  Local industriel. commercial ou assimilé
# 459                    0.00                                Dépendance
# 6313                   0.00                                      None
# 7727                   0.00                               Appartement
# 6256                  26.42                               Appartement
# 268                    0.00                                Dépendance
# 3746                   0.00                                Dépendance
# 248                    0.00  Local industriel. commercial ou assimilé
# 8823                 141.64                               Appartement

# %%
#ordering columns for better visibility
db=db[['id_mutation',
       'date_mutation', 
       'nature_mutation',
       'type_local',
       'nombre_pieces_principales',
       'valeur_fonciere',
       'surface_carrez_total',
       'surface_reelle_bati',
       'surface_terrain',
       'adresse_numero', 
       'adresse_suffixe', 
       'adresse_nom_voie', 
       'code_postal', 
       'nom_commune',
       'adresse_code_voie',
       'code_commune',
       'section_prefixe',
       'id_parcelle',  
       'longitude', 
       'latitude']]
db
# Out:
#         id_mutation date_mutation nature_mutation  \
# 0      2019-1072649    2019-12-23           Vente
# 1      2019-1072739    2019-12-19           Vente
# 2      2019-1072673    2019-12-16           Vente
# 3      2019-1072512    2019-12-13           Vente
# 4      2019-1072512    2019-12-13           Vente
# ...             ...           ...             ...
# 13933  2014-1059819    2014-01-13           Vente
# 13934  2014-1059714    2014-01-10           Vente
# 13935  2014-1059717    2014-01-10           Vente
# 13936  2014-1059717    2014-01-10           Vente
# 13937  2014-1059709    2014-01-09           Vente
#
#                                      type_local  nombre_pieces_principales  \
# 0                                   Appartement                          4
# 1      Local industriel. commercial ou assimilé                          0
# 2                                    Dépendance                          0
# 3                                   Appartement                          5
# 4                                   Appartement                          1
# ...                                         ...                        ...
# 13933                               Appartement                          1
# 13934                               Appartement                          3
# 13935                                Dépendance                          0
# 13936                                Dépendance                          0
# 13937                               Appartement                          3
#
#        valeur_fonciere  surface_carrez_total  surface_reelle_bati  \
# 0             665000.0                 57.40                 55.0
# 1           18300000.0                  0.00                693.0
# 2              71000.0                  0.00                  0.0
# 3            1520000.0                125.75                123.0
# 4            1520000.0                  5.57                  6.0
# ...                ...                   ...                  ...
# 13933         252000.0                  0.00                 25.0
# 13934         540000.0                 59.75                 60.0
# 13935         102000.0                  0.00                  0.0
# 13936         102000.0                  0.00                  0.0
# 13937         443000.0                  0.00                 43.0
#
#        surface_terrain adresse_numero adresse_suffixe     adresse_nom_voie  \
# 0                  0.0             47            None         RUE DE DOUAI
# 1                  0.0            106            None      RUE D AMSTERDAM
# 2                  0.0             14            None            RUE BALLU
# 3                  0.0              1            None       PL ADOLPHE MAX
# 4                  0.0              1            None       PL ADOLPHE MAX
# ...                ...            ...             ...                  ...
# 13933              0.0             10            None  RUE DE ROCHECHOUART
# 13934              0.0             10            None           RUE MAYRAN
# 13935              0.0              4            None       RUE ROCHAMBEAU
# 13936              0.0              4            None       RUE ROCHAMBEAU
# 13937              0.0             29            None     RUE DE BELLEFOND
#
#       code_postal              nom_commune adresse_code_voie code_commune  \
# 0           75009  Paris 9e Arrondissement              2909        75109
# 1           75009  Paris 9e Arrondissement              0300        75109
# 2           75009  Paris 9e Arrondissement              0646        75109
# 3           75009  Paris 9e Arrondissement              0065        75109
# 4           75009  Paris 9e Arrondissement              0065        75109
# ...           ...                      ...               ...          ...
# 13933       75009  Paris 9e Arrondissement              8289        75109
# 13934       75009  Paris 9e Arrondissement              6223        75109
# 13935       75009  Paris 9e Arrondissement              8283        75109
# 13936       75009  Paris 9e Arrondissement              8283        75109
# 13937       75009  Paris 9e Arrondissement              0827        75109
#
#       section_prefixe id_parcelle  longitude   latitude
# 0               000AA        0044   2.330953  48.882913
# 1               000AA        0119   2.327339  48.883026
# 2               000AA        0065   2.330517  48.882159
# 3               000AA        0040   2.330485  48.883136
# 4               000AA        0040   2.330485  48.883136
# ...               ...         ...        ...        ...
# 13933           000BF        0067   2.345008  48.877038
# 13934           000BF        0009   2.344981  48.877407
# 13935           000BF        0024   2.346670  48.877538
# 13936           000BF        0024   2.346670  48.877538
# 13937           000BF        0018   2.346413  48.877644
#
# [13938 rows x 20 columns]

# %% [markdown]
# # Checking the values for the column 'type_local'

# %%
# to understand what is Dépendance and None 
# and if some rows in those categories must be part of the existant surface study for flats

# %%
# understand all types
db['type_local'].unique()
# Out:
# array(['Appartement', 'Local industriel. commercial ou assimilé',
#        'Dépendance', 'Maison', 'None'], dtype=object)

# %%
# checking values for Maison, that categorie will probably outliers from our study.
db.loc[db['type_local'] == 'Maison']
# Out:
#         id_mutation date_mutation nature_mutation type_local  \
# 253    2017-1408491    2017-06-28           Vente     Maison
# 2547   2017-1407077    2017-02-24           Vente     Maison
# 2571   2016-1241239    2016-07-22           Vente     Maison
# 2615   2015-1151725    2015-03-31           Vente     Maison
# 2651   2014-1060169    2014-03-12           Vente     Maison
# 2957   2016-1241897    2016-09-16           Vente     Maison
# 3410   2016-1240625    2016-05-31           Vente     Maison
# 10326  2019-1069742    2019-04-12           Vente     Maison
#
#        nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 253                            6        2918700.0                  0.00
# 2547                           7        2800000.0                  0.00
# 2571                           7        5850000.0                335.62
# 2615                           2        1660500.0                  0.00
# 2651                           8         320000.0                  0.00
# 2957                           4        3400000.0                  0.00
# 3410                           8        2309375.0                154.53
# 10326                          4        3960000.0                  0.00
#
#        surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 253                  205.0              0.0             20            None
# 2547                 280.0            139.0             14            None
# 2571                 349.0              0.0             10            None
# 2615                  76.0            137.0              6            None
# 2651                 268.0            152.0              8            None
# 2957                 189.0            250.0             58               C
# 3410                 181.0              0.0             25            None
# 10326                273.0              0.0             38               B
#
#                 adresse_nom_voie code_postal              nom_commune  \
# 253                    RUE BALLU       75009  Paris 9e Arrondissement
# 2547            CITE MALESHERBES       75009  Paris 9e Arrondissement
# 2571                  AV FROCHOT       75009  Paris 9e Arrondissement
# 2615                  AV FROCHOT       75009  Paris 9e Arrondissement
# 2651            CITE MALESHERBES       75009  Paris 9e Arrondissement
# 2957     RUE DE LA ROCHEFOUCAULD       75009  Paris 9e Arrondissement
# 3410             RUE DES MARTYRS       75009  Paris 9e Arrondissement
# 10326  RUE DE LA TOUR D AUVERGNE       75009  Paris 9e Arrondissement
#
#       adresse_code_voie code_commune section_prefixe id_parcelle  longitude  \
# 253                0646        75109           000AA        0080   2.330153
# 2547               5952        75109           000AE        0054   2.338854
# 2571               3870        75109           000AE        0026   2.338080
# 2615               3870        75109           000AE        0084   2.337988
# 2651               5952        75109           000AE        0057   2.339252
# 2957               5356        75109           000AF        0010   2.336517
# 3410               6147        75109           000AG        0028   2.339377
# 10326              5381        75109           000BA        0144   2.341889
#
#         latitude
# 253    48.882111
# 2547   48.881237
# 2571   48.881874
# 2615   48.881696
# 2651   48.881163
# 2957   48.880336
# 3410   48.878566
# 10326  48.879834

# %%
# we can see here the ratio €/m² for Maison is quite high.
House = db.loc[db['type_local'] == 'Maison']
print('average price: ',round((House['valeur_fonciere'] / House['surface_reelle_bati']).mean()), '€ / m²')
# Out:
# average price:  13662 € / m²

# %%
# check nb of transactions for ['type_local'] == 'Appartement'
db.loc[db['type_local'] == 'Appartement']
# Out:
#         id_mutation date_mutation nature_mutation   type_local  \
# 0      2019-1072649    2019-12-23           Vente  Appartement
# 3      2019-1072512    2019-12-13           Vente  Appartement
# 4      2019-1072512    2019-12-13           Vente  Appartement
# 7      2019-1072404    2019-12-04           Vente  Appartement
# 10     2019-1072405    2019-12-02           Vente  Appartement
# ...             ...           ...             ...          ...
# 13929  2014-1059868    2014-01-30           Vente  Appartement
# 13931  2014-1059857    2014-01-29           Vente  Appartement
# 13933  2014-1059819    2014-01-13           Vente  Appartement
# 13934  2014-1059714    2014-01-10           Vente  Appartement
# 13937  2014-1059709    2014-01-09           Vente  Appartement
#
#        nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 0                              4         665000.0                 57.40
# 3                              5        1520000.0                125.75
# 4                              1        1520000.0                  5.57
# 7                              3         602000.0                 52.60
# 10                             7         608250.0                 46.53
# ...                          ...              ...                   ...
# 13929                          4         725527.0                  0.00
# 13931                          1         346000.0                  0.00
# 13933                          1         252000.0                  0.00
# 13934                          3         540000.0                 59.75
# 13937                          3         443000.0                  0.00
#
#        surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 0                     55.0              0.0             47            None
# 3                    123.0              0.0              1            None
# 4                      6.0              0.0              1            None
# 7                     54.0              0.0             39            None
# 10                   150.0              0.0             14            None
# ...                    ...              ...            ...             ...
# 13929                 75.0              0.0             13            None
# 13931                 25.0              0.0             10            None
# 13933                 25.0              0.0             10            None
# 13934                 60.0              0.0             10            None
# 13937                 43.0              0.0             29            None
#
#           adresse_nom_voie code_postal              nom_commune  \
# 0             RUE DE DOUAI       75009  Paris 9e Arrondissement
# 3           PL ADOLPHE MAX       75009  Paris 9e Arrondissement
# 4           PL ADOLPHE MAX       75009  Paris 9e Arrondissement
# 7             RUE DE DOUAI       75009  Paris 9e Arrondissement
# 10        RUE DE BRUXELLES       75009  Paris 9e Arrondissement
# ...                    ...         ...                      ...
# 13929     RUE DE BELLEFOND       75009  Paris 9e Arrondissement
# 13931  RUE DE ROCHECHOUART       75009  Paris 9e Arrondissement
# 13933  RUE DE ROCHECHOUART       75009  Paris 9e Arrondissement
# 13934           RUE MAYRAN       75009  Paris 9e Arrondissement
# 13937     RUE DE BELLEFOND       75009  Paris 9e Arrondissement
#
#       adresse_code_voie code_commune section_prefixe id_parcelle  longitude  \
# 0                  2909        75109           000AA        0044   2.330953
# 3                  0065        75109           000AA        0040   2.330485
# 4                  0065        75109           000AA        0040   2.330485
# 7                  2909        75109           000AA        0048   2.331604
# 10                 1345        75109           000AA        0015   2.330999
# ...                 ...          ...             ...         ...        ...
# 13929              0827        75109           000BF        0037   2.347690
# 13931              8289        75109           000BF        0067   2.345008
# 13933              8289        75109           000BF        0067   2.345008
# 13934              6223        75109           000BF        0009   2.344981
# 13937              0827        75109           000BF        0018   2.346413
#
#         latitude
# 0      48.882913
# 3      48.883136
# 4      48.883136
# 7      48.882716
# 10     48.883720
# ...          ...
# 13929  48.877414
# 13931  48.877038
# 13933  48.877038
# 13934  48.877407
# 13937  48.877644
#
# [8566 rows x 20 columns]

# %%
# check nb of transactions for ['type_local'] == 'Dépendance'
db.loc[db['type_local'] == 'Dépendance']
# Out:
#         id_mutation date_mutation nature_mutation  type_local  \
# 2      2019-1072673    2019-12-16           Vente  Dépendance
# 5      2019-1072512    2019-12-13           Vente  Dépendance
# 6      2019-1072512    2019-12-13           Vente  Dépendance
# 8      2019-1072486    2019-12-04           Vente  Dépendance
# 9      2019-1072379    2019-12-03           Vente  Dépendance
# ...             ...           ...             ...         ...
# 13920  2014-1060188    2014-02-28           Vente  Dépendance
# 13921  2014-1060188    2014-02-28           Vente  Dépendance
# 13930  2014-1059868    2014-01-30           Vente  Dépendance
# 13935  2014-1059717    2014-01-10           Vente  Dépendance
# 13936  2014-1059717    2014-01-10           Vente  Dépendance
#
#        nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 2                              0          71000.0                  0.00
# 5                              0        1520000.0                  6.68
# 6                              0        1520000.0                  4.07
# 8                              0          63000.0                  7.00
# 9                              0          25000.0                  3.65
# ...                          ...              ...                   ...
# 13920                          0        1200000.0                132.22
# 13921                          0        1200000.0                132.22
# 13930                          0         725527.0                  0.00
# 13935                          0         102000.0                  0.00
# 13936                          0         102000.0                  0.00
#
#        surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 2                      0.0              0.0             14            None
# 5                      0.0              0.0              1            None
# 6                      0.0              0.0              1            None
# 8                      0.0              0.0             45            None
# 9                      0.0              0.0             24            None
# ...                    ...              ...            ...             ...
# 13920                  0.0              0.0              4            None
# 13921                  0.0              0.0              4            None
# 13930                  0.0              0.0             13            None
# 13935                  0.0              0.0              4            None
# 13936                  0.0              0.0              4            None
#
#         adresse_nom_voie code_postal              nom_commune  \
# 2              RUE BALLU       75009  Paris 9e Arrondissement
# 5         PL ADOLPHE MAX       75009  Paris 9e Arrondissement
# 6         PL ADOLPHE MAX       75009  Paris 9e Arrondissement
# 8           RUE DE DOUAI       75009  Paris 9e Arrondissement
# 9      RUE DE VINTIMILLE       75009  Paris 9e Arrondissement
# ...                  ...         ...                      ...
# 13920  RUE PIERRE SEMARD       75009  Paris 9e Arrondissement
# 13921  RUE PIERRE SEMARD       75009  Paris 9e Arrondissement
# 13930   RUE DE BELLEFOND       75009  Paris 9e Arrondissement
# 13935     RUE ROCHAMBEAU       75009  Paris 9e Arrondissement
# 13936     RUE ROCHAMBEAU       75009  Paris 9e Arrondissement
#
#       adresse_code_voie code_commune section_prefixe id_parcelle  longitude  \
# 2                  0646        75109           000AA        0065   2.330517
# 5                  0065        75109           000AA        0040   2.330485
# 6                  0065        75109           000AA        0040   2.330485
# 8                  2909        75109           000AA        0045   2.331158
# 9                  9866        75109           000AA        0060   2.329910
# ...                 ...          ...             ...         ...        ...
# 13920              7479        75109           000BF        0031   2.347352
# 13921              7479        75109           000BF        0031   2.347352
# 13930              0827        75109           000BF        0037   2.347690
# 13935              8283        75109           000BF        0024   2.346670
# 13936              8283        75109           000BF        0024   2.346670
#
#         latitude
# 2      48.882159
# 5      48.883136
# 6      48.883136
# 8      48.882895
# 9      48.882595
# ...          ...
# 13920  48.877117
# 13921  48.877117
# 13930  48.877414
# 13935  48.877538
# 13936  48.877538
#
# [2668 rows x 20 columns]

# %%
db.loc[(db['type_local'] == 'Dépendance') & (db['surface_carrez_total'] == 0)]
# Out:
#         id_mutation date_mutation nature_mutation  type_local  \
# 2      2019-1072673    2019-12-16           Vente  Dépendance
# 13     2019-1072226    2019-11-14           Vente  Dépendance
# 16     2019-1072104    2019-11-07           Vente  Dépendance
# 18     2019-1071997    2019-10-29           Vente  Dépendance
# 23     2019-1071992    2019-10-10           Vente  Dépendance
# ...             ...           ...             ...         ...
# 13898  2014-1061540    2014-07-30           Vente  Dépendance
# 13899  2014-1061540    2014-07-30           Vente  Dépendance
# 13930  2014-1059868    2014-01-30           Vente  Dépendance
# 13935  2014-1059717    2014-01-10           Vente  Dépendance
# 13936  2014-1059717    2014-01-10           Vente  Dépendance
#
#        nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 2                              0          71000.0                   0.0
# 13                             0        1430000.0                   0.0
# 16                             0          60000.0                   0.0
# 18                             0          23000.0                   0.0
# 23                             0         730000.0                   0.0
# ...                          ...              ...                   ...
# 13898                          0          75000.0                   0.0
# 13899                          0          75000.0                   0.0
# 13930                          0         725527.0                   0.0
# 13935                          0         102000.0                   0.0
# 13936                          0         102000.0                   0.0
#
#        surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 2                      0.0              0.0             14            None
# 13                     0.0              0.0             14            None
# 16                     0.0              0.0             61            None
# 18                     0.0              0.0             24            None
# 23                     0.0              0.0            100            None
# ...                    ...              ...            ...             ...
# 13898                  0.0              0.0              4            None
# 13899                  0.0              0.0              4            None
# 13930                  0.0              0.0             13            None
# 13935                  0.0              0.0              4            None
# 13936                  0.0              0.0              4            None
#
#         adresse_nom_voie code_postal              nom_commune  \
# 2              RUE BALLU       75009  Paris 9e Arrondissement
# 13      RUE DE BRUXELLES       75009  Paris 9e Arrondissement
# 16          RUE DE DOUAI       75009  Paris 9e Arrondissement
# 18     RUE DE VINTIMILLE       75009  Paris 9e Arrondissement
# 23       RUE D AMSTERDAM       75009  Paris 9e Arrondissement
# ...                  ...         ...                      ...
# 13898     RUE ROCHAMBEAU       75009  Paris 9e Arrondissement
# 13899     RUE ROCHAMBEAU       75009  Paris 9e Arrondissement
# 13930   RUE DE BELLEFOND       75009  Paris 9e Arrondissement
# 13935     RUE ROCHAMBEAU       75009  Paris 9e Arrondissement
# 13936     RUE ROCHAMBEAU       75009  Paris 9e Arrondissement
#
#       adresse_code_voie code_commune section_prefixe id_parcelle  longitude  \
# 2                  0646        75109           000AA        0065   2.330517
# 13                 1345        75109           000AA        0015   2.330999
# 16                 2909        75109           000AA        0131   2.329053
# 18                 9866        75109           000AA        0060   2.329910
# 23                 0300        75109           000AA        0149   2.327471
# ...                 ...          ...             ...         ...        ...
# 13898              8283        75109           000BF        0024   2.346670
# 13899              8283        75109           000BF        0024   2.346670
# 13930              0827        75109           000BF        0037   2.347690
# 13935              8283        75109           000BF        0024   2.346670
# 13936              8283        75109           000BF        0024   2.346670
#
#         latitude
# 2      48.882159
# 13     48.883720
# 16     48.883425
# 18     48.882595
# 23     48.882673
# ...          ...
# 13898  48.877538
# 13899  48.877538
# 13930  48.877414
# 13935  48.877538
# 13936  48.877538
#
# [2086 rows x 20 columns]

# %%
db.loc[(db['type_local'] == 'Dépendance') & (db['surface_carrez_total'] == 0) & (db['surface_reelle_bati'] != 0)].head()
# Out:
#        id_mutation date_mutation nature_mutation  type_local  \
# 3969  2016-1240480    2016-06-01           Vente  Dépendance
# 4134  2014-1061393    2014-06-30           Vente  Dépendance
# 4135  2014-1061393    2014-06-30           Vente  Dépendance
# 4136  2014-1061393    2014-06-30           Vente  Dépendance
# 4139  2014-1061393    2014-06-30           Vente  Dépendance
#
#       nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 3969                          0          29000.0                   0.0
# 4134                          0         378000.0                   0.0
# 4135                          0         378000.0                   0.0
# 4136                          0         378000.0                   0.0
# 4139                          0         378000.0                   0.0
#
#       surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 3969                 10.0              0.0              6            None
# 4134                 11.0              0.0              6            None
# 4135                 11.0              0.0              6            None
# 4136                 11.0              0.0              6            None
# 4139                 11.0              0.0              6            None
#
#              adresse_nom_voie code_postal              nom_commune  \
# 3969  RUE DE LA ROCHEFOUCAULD       75009  Paris 9e Arrondissement
# 4134  RUE DE LA ROCHEFOUCAULD       75009  Paris 9e Arrondissement
# 4135  RUE DE LA ROCHEFOUCAULD       75009  Paris 9e Arrondissement
# 4136  RUE DE LA ROCHEFOUCAULD       75009  Paris 9e Arrondissement
# 4139  RUE DE LA ROCHEFOUCAULD       75009  Paris 9e Arrondissement
#
#      adresse_code_voie code_commune section_prefixe id_parcelle  longitude  \
# 3969              5356        75109           000AH        0028   2.334807
# 4134              5356        75109           000AH        0028   2.334807
# 4135              5356        75109           000AH        0028   2.334807
# 4136              5356        75109           000AH        0028   2.334807
# 4139              5356        75109           000AH        0028   2.334807
#
#        latitude
# 3969  48.877486
# 4134  48.877486
# 4135  48.877486
# 4136  48.877486
# 4139  48.877486

# %%
check = db.loc[(db['type_local'] == 'Dépendance') & (db['surface_carrez_total'] == 0) & (db['surface_reelle_bati'] != 0)]
check[['surface_reelle_bati','valeur_fonciere']].mean()
# Out:
# surface_reelle_bati    1.176316e+01
# valeur_fonciere        1.626103e+07
# dtype: float64

# %%
db['surface_terrain']=db['surface_terrain'].replace('nan', 'Non renseigné')
db['surface_terrain']=db['surface_terrain'].replace('None', 'Non renseigné')

# %%
# une surface habitable de 9 m² et une hauteur sous plafond minimale de 2,20 mètres,
db.loc[(db['type_local'] == 'Dépendance') & (db['surface_carrez_total'] != 0) & (db['surface_carrez_total'] > 9)]
# Out:
#         id_mutation date_mutation nature_mutation  type_local  \
# 20     2019-1072132    2019-10-24           Vente  Dépendance
# 68     2019-1071087    2019-07-31           Vente  Dépendance
# 71     2019-1071223    2019-07-24           Vente  Dépendance
# 96     2019-1069597    2019-04-05           Vente  Dépendance
# 107    2019-1069445    2019-03-08           Vente  Dépendance
# ...             ...           ...             ...         ...
# 13853  2015-1153106    2015-09-04           Vente  Dépendance
# 13857  2015-1152621    2015-07-22           Vente  Dépendance
# 13890  2014-1061985    2014-08-29           Vente  Dépendance
# 13920  2014-1060188    2014-02-28           Vente  Dépendance
# 13921  2014-1060188    2014-02-28           Vente  Dépendance
#
#        nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 20                             0         105400.0                 10.75
# 68                             0         220096.0                 18.13
# 71                             0         158000.0                 12.85
# 96                             0         185000.0                 15.20
# 107                            0         161905.0                 16.46
# ...                          ...              ...                   ...
# 13853                          0         990000.0                132.46
# 13857                          0          58000.0                 11.45
# 13890                          0         840000.0                118.37
# 13920                          0        1200000.0                132.22
# 13921                          0        1200000.0                132.22
#
#        surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 20                     0.0              0.0             36            None
# 68                     0.0              0.0             44            None
# 71                     0.0              0.0              7            None
# 96                     0.0              0.0              6            None
# 107                    0.0              0.0              6            None
# ...                    ...              ...            ...             ...
# 13853                  0.0              0.0             31            None
# 13857                  0.0              0.0             87            None
# 13890                  0.0              0.0              6            None
# 13920                  0.0              0.0              4            None
# 13921                  0.0              0.0              4            None
#
#         adresse_nom_voie code_postal              nom_commune  \
# 20             RUE BALLU       75009  Paris 9e Arrondissement
# 68      RUE DE BRUXELLES       75009  Paris 9e Arrondissement
# 71      RUE PIERRE HARET       75009  Paris 9e Arrondissement
# 96         RUE DE CALAIS       75009  Paris 9e Arrondissement
# 107        RUE DE CALAIS       75009  Paris 9e Arrondissement
# ...                  ...         ...                      ...
# 13853   RUE DE BELLEFOND       75009  Paris 9e Arrondissement
# 13857     RUE LA FAYETTE       75009  Paris 9e Arrondissement
# 13890         RUE MAYRAN       75009  Paris 9e Arrondissement
# 13920  RUE PIERRE SEMARD       75009  Paris 9e Arrondissement
# 13921  RUE PIERRE SEMARD       75009  Paris 9e Arrondissement
#
#       adresse_code_voie code_commune section_prefixe id_parcelle  longitude  \
# 20                 0646        75109           000AA        0091   2.328767
# 68                 1345        75109           000AA        0135   2.328116
# 71                 7441        75109           000AA        0007   2.330399
# 96                 1434        75109           000AA        0054   2.331406
# 107                1434        75109           000AA        0054   2.331406
# ...                 ...          ...             ...         ...        ...
# 13853              0827        75109           000BF        0017   2.346219
# 13857              5240        75109           000BF        0040   2.348222
# 13890              6223        75109           000BF        0011   2.345424
# 13920              7479        75109           000BF        0031   2.347352
# 13921              7479        75109           000BF        0031   2.347352
#
#         latitude
# 20     48.882457
# 68     48.882942
# 71     48.884003
# 96     48.882596
# 107    48.882596
# ...          ...
# 13853  48.877774
# 13857  48.877231
# 13890  48.877396
# 13920  48.877117
# 13921  48.877117
#
# [315 rows x 20 columns]

# %%
db.loc[(db['type_local'] == 'Dépendance') & (db['surface_carrez_total'] != 0)].mean()
# Out:
# nombre_pieces_principales    0.000000e+00
# valeur_fonciere              4.372691e+05
# surface_carrez_total         3.424936e+01
# surface_reelle_bati          0.000000e+00
# surface_terrain              0.000000e+00
# code_postal                           inf
# adresse_code_voie                     inf
# code_commune                          inf
# id_parcelle                           inf
# longitude                    2.337798e+00
# latitude                     4.887946e+01
# dtype: float64

# %% [markdown]
# # Saving Expropriation DB for future comparaison

# %%
db_expro = db.loc[db['nature_mutation'] == 'Expropriation']
db_expro
# Out:
#        id_mutation date_mutation nature_mutation type_local  \
# 1250  2014-1063066    2014-05-13   Expropriation       None
# 1251  2014-1063067    2014-05-13   Expropriation       None
# 1252  2014-1063068    2014-05-13   Expropriation       None
# 1253  2014-1063069    2014-05-13   Expropriation       None
# 1254  2014-1063070    2014-05-13   Expropriation       None
# 1255  2014-1063071    2014-05-13   Expropriation       None
# 1256  2014-1063076    2014-05-13   Expropriation       None
# 5005  2014-1063072    2014-05-13   Expropriation       None
# 5006  2014-1063073    2014-05-13   Expropriation       None
# 5007  2014-1063074    2014-05-13   Expropriation       None
# 5008  2014-1063075    2014-05-13   Expropriation       None
# 5009  2014-1063077    2014-05-13   Expropriation       None
#
#       nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# 1250                          0          37272.0                   0.0
# 1251                          0          61064.0                   0.0
# 1252                          0         166758.0                   0.0
# 1253                          0         176698.0                   0.0
# 1254                          0          84469.0                   0.0
# 1255                          0         203125.0                   0.0
# 1256                          0           7678.0                   0.0
# 5005                          0          58233.0                   0.0
# 5006                          0         173460.0                   0.0
# 5007                          0           8747.0                   0.0
# 5008                          0         202398.0                   0.0
# 5009                          0         146813.0                   0.0
#
#       surface_reelle_bati  surface_terrain adresse_numero adresse_suffixe  \
# 1250                  0.0              0.0           74.0            None
# 1251                  0.0              0.0           72.0            None
# 1252                  0.0              0.0           70.0            None
# 1253                  0.0              0.0           66.0            None
# 1254                  0.0              0.0           60.0            None
# 1255                  0.0              0.0           16.0            None
# 1256                  0.0              0.0           76.0            None
# 5005                  0.0              0.0           15.0            None
# 5006                  0.0              0.0           17.0            None
# 5007                  0.0              0.0           54.0            None
# 5008                  0.0              0.0           50.0            None
# 5009                  0.0              0.0           48.0            None
#
#      adresse_nom_voie code_postal              nom_commune adresse_code_voie  \
# 1250  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 1251  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 1252  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 1253  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 1254  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 1255     RUE DE LIEGE       75009  Paris 9e Arrondissement              5665
# 1256  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 5005     RUE DE LIEGE       75009  Paris 9e Arrondissement              5665
# 5006     RUE DE LIEGE       75009  Paris 9e Arrondissement              5665
# 5007  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 5008  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
# 5009  RUE D AMSTERDAM       75009  Paris 9e Arrondissement              0300
#
#      code_commune section_prefixe id_parcelle  longitude   latitude
# 1250        75109           000AB        0119   2.327401  48.880914
# 1251        75109           000AB        0118   2.327398  48.880848
# 1252        75109           000AB        0112   2.327532  48.880619
# 1253        75109           000AB        0108   2.327518  48.880197
# 1254        75109           000AB        0106   2.327340  48.879891
# 1255        75109           000AB        0105   2.327489  48.879966
# 1256        75109           000AB        0120   2.327416  48.881063
# 5005        75109           000AJ        0005   2.327569  48.879393
# 5006        75109           000AJ        0004   2.327299  48.879410
# 5007        75109           000AJ        0003   2.327215  48.879340
# 5008        75109           000AJ        0086   2.327475  48.879046
# 5009        75109           000AJ        0008   2.327295  48.878874

# %%
#export command to get the CSV file for Flats transaction
db_expro.to_csv('Paris9e_Expropriations.csv', sep='/', index=False)

# %% [markdown]
# # Removing not required or usable Rows

# %%
# we are going to focus our study an the existing m² for flats.
# meaning we are going to keep the 'Appartements' and clean the unusable data 
# keep from the Dépendance family all the m² that we will consider as flats
# all expropriation transaction also must be removed
# check and remove potential duplicates

# %%
db.head()
# Out:
#     id_mutation date_mutation nature_mutation  \
# 0  2019-1072649    2019-12-23           Vente
# 1  2019-1072739    2019-12-19           Vente
# 2  2019-1072673    2019-12-16           Vente
# 3  2019-1072512    2019-12-13           Vente
# 4  2019-1072512    2019-12-13           Vente
#
#                                  type_local  nombre_pieces_principales  \
# 0                               Appartement                          4
# 1  Local industriel. commercial ou assimilé                          0
# 2                                Dépendance                          0
# 3                               Appartement                          5
# 4                               Appartement                          1
#
#    valeur_fonciere  surface_carrez_total  surface_reelle_bati  \
# 0         665000.0                 57.40                 55.0
# 1       18300000.0                  0.00                693.0
# 2          71000.0                  0.00                  0.0
# 3        1520000.0                125.75                123.0
# 4        1520000.0                  5.57                  6.0
#
#    surface_terrain adresse_numero adresse_suffixe adresse_nom_voie  \
# 0              0.0             47            None     RUE DE DOUAI
# 1              0.0            106            None  RUE D AMSTERDAM
# 2              0.0             14            None        RUE BALLU
# 3              0.0              1            None   PL ADOLPHE MAX
# 4              0.0              1            None   PL ADOLPHE MAX
#
#   code_postal              nom_commune adresse_code_voie code_commune  \
# 0       75009  Paris 9e Arrondissement              2909        75109
# 1       75009  Paris 9e Arrondissement              0300        75109
# 2       75009  Paris 9e Arrondissement              0646        75109
# 3       75009  Paris 9e Arrondissement              0065        75109
# 4       75009  Paris 9e Arrondissement              0065        75109
#
#   section_prefixe id_parcelle  longitude   latitude
# 0           000AA        0044   2.330953  48.882913
# 1           000AA        0119   2.327339  48.883026
# 2           000AA        0065   2.330517  48.882159
# 3           000AA        0040   2.330485  48.883136
# 4           000AA        0040   2.330485  48.883136

# %%
db['type_local'].unique()
# Out:
# array(['Appartement', 'Local industriel. commercial ou assimilé',
#        'Dépendance', 'Maison', 'None'], dtype=object)

# %%
# checking if some transaction defined as None and not VEFA could be interesting to study.
# but in fact, we don't have any surface for those ones
Nonetest = db[(db['type_local'] == 'None') & (db['nature_mutation'] != 'Vente en l\'état futur d\'achèvement') & (db['nature_mutation'] != 'Expropriation')]
Nonetest.describe()
# Out:
#        nombre_pieces_principales  valeur_fonciere  surface_carrez_total  \
# count                      123.0     1.200000e+02                 123.0
# mean                         0.0     1.071463e+08                   0.0
# std                          0.0     1.304282e+08                   0.0
# min                          0.0     1.200000e+00                   0.0
# 25%                          0.0     1.692000e+06                   0.0
# 50%                          0.0     4.192500e+07                   0.0
# 75%                          0.0     2.050000e+08                   0.0
# max                          0.0     4.210000e+08                   0.0
#
#        surface_reelle_bati  surface_terrain   longitude    latitude
# count                123.0       123.000000  123.000000  123.000000
# mean                   0.0        79.837398    2.333110   48.875852
# std                    0.0       211.142884    0.005890    0.002679
# min                    0.0         0.000000    2.326988   48.871187
# 25%                    0.0         0.000000    2.328182   48.874289
# 50%                    0.0         0.000000    2.330440   48.875687
# 75%                    0.0         0.000000    2.336617   48.876927
# max                    0.0      1401.000000    2.348269   48.883241

# %%
db.columns
# Out:
# Index(['id_mutation', 'date_mutation', 'nature_mutation', 'type_local',
#        'nombre_pieces_principales', 'valeur_fonciere', 'surface_carrez_total',
#        'surface_reelle_bati', 'surface_terrain', 'adresse_numero',
#        'adresse_suffixe', 'adresse_nom_voie', 'code_postal', 'nom_commune',
#        'adresse_code_voie', 'code_commune', 'section_prefixe', 'id_parcelle',
#        'longitude', 'latitude'],
#       dtype='object')

# %%
index1 = db[(db['type_local'] == 'Appartement') & (db['surface_carrez_total'] == 0) & (db['surface_reelle_bati'] == 0)].index
index2 = db[(db['type_local'] == 'Dépendance') & (db['surface_carrez_total'] == 0) & (db['surface_carrez_total'] < 9)].index
index3 = db[db['nature_mutation'] == 'Expropriation'].index
index4 = db[db['type_local'] == 'Local industriel. commercial ou assimilé'].index
index5 = db[db['type_local'] == 'Maison'].index
# Warining : we will have to consider durface relle bati if Carrez =0

# %%
#index = index1 + index2 + index3 + index4 + index5

# %%
#dropping rows not needed 
#total rows 13938 - 4559 = 9379
db.drop(index=index1, inplace=True)
db.drop(index=index2, inplace=True)
db.drop(index=index3, inplace=True)
db.drop(index=index4, inplace=True)
db.drop(index=index5, inplace=True)

# %% [markdown]
# # Creating tables from the database

# %%
# We apply function to each column and use a group by on id_mutation and price
db_general=db.groupby(['id_mutation','valeur_fonciere']).agg({'nombre_pieces_principales':'sum',
                         'surface_carrez_total':'sum',
                         'surface_reelle_bati':'sum',
                         'surface_terrain':'sum',
                         'type_local': lambda x: (stats.mode(x)[0]),
                         'date_mutation':lambda x: (stats.mode(x)[0]),
                         'nature_mutation':lambda x: (stats.mode(x)[0]),
                         'adresse_numero':lambda x: (stats.mode(x)[0]),
                         'adresse_suffixe':lambda x: (stats.mode(x)[0]),
                         'adresse_nom_voie':lambda x: (stats.mode(x)[0]),
                         'code_postal':lambda x: (stats.mode(x)[0]),
                         'nom_commune':lambda x: (stats.mode(x)[0]),
                         'adresse_code_voie':lambda x: (stats.mode(x)[0]),
                         'code_commune':lambda x: (stats.mode(x)[0]),
                         'section_prefixe':lambda x: (stats.mode(x)[0]),
                         'id_parcelle':lambda x: (stats.mode(x)[0]),
                         'longitude':lambda x: (stats.mode(x)[0]),
                         'latitude':lambda x: (stats.mode(x)[0])}).reset_index()

# %%
# We create a new column to analyze the number of rooms

# create a list of our conditions
conditions = [
    (db_general['nombre_pieces_principales'] <= 1),
    (db_general['nombre_pieces_principales'] ==2),
    (db_general['nombre_pieces_principales'] ==3),
    (db_general['nombre_pieces_principales'] ==4),
    (db_general['nombre_pieces_principales'] > 4)
    ]

# create a list of the values we want to assign for each condition
values = ['1', '2', '3', '4', '5+']

# create a new column and use np.select to assign values to it using our lists as arguments
db_general['nb_piece'] = np.select(conditions, values)

# %%
# We create 2 new columns, in order to calculate the price/surface for carrez and bati
db_general['valeur_fonciere/surface_carrez']=db_general['valeur_fonciere'] / db_general['surface_carrez_total']
db_general['valeur_fonciere/surface_bati']=db_general['valeur_fonciere'] / db_general['surface_reelle_bati']

# %%
# We create a new table in order to analyze the surface carrez
db_surface_carrez=db_general[db_general['surface_carrez_total']!=0]

# %%
# We create a new table in order to analyze the surface bati
db_surface_bati=db_general[db_general['surface_reelle_bati']!=0]

# %%
sns.boxplot(db_surface_carrez['valeur_fonciere/surface_carrez'])
# Out:
# <AxesSubplot:xlabel='valeur_fonciere/surface_carrez'>

# %%
sns.boxplot(db_surface_bati['valeur_fonciere/surface_bati'])
# Out:
# <AxesSubplot:xlabel='valeur_fonciere/surface_bati'>

# %%
# We define a function to remove outliers
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
# We create a new table without outliers for carrez
db_surface_carrez_not_outliers=remove_outlier(db_surface_carrez, 'valeur_fonciere/surface_carrez')
sns.boxplot(db_surface_carrez_not_outliers['valeur_fonciere/surface_carrez'])
# Out:
# <AxesSubplot:xlabel='valeur_fonciere/surface_carrez'>

# %%
# We create a new table without outliers for carrez
db_surface_bati_not_outliers=remove_outlier(db_surface_bati, 'valeur_fonciere/surface_bati')
sns.boxplot(db_surface_bati_not_outliers['valeur_fonciere/surface_bati'])
# Out:
# <AxesSubplot:xlabel='valeur_fonciere/surface_bati'>

# %% [markdown]
# # Export

# %%
#export command to get the CSV file for Flats transaction (GENERAL)
db_general.to_csv('Paries9e_General.csv', sep='/', index=False)

# %%
#export command to get the CSV file for Flats transaction (CARREZ)
db_surface_carrez.to_csv('Paris9e_Transactions_Carrez.csv', sep='/', index=False)

# %%
#export command to get the CSV file for Flats transaction (CARREZ_not_outliers)
db_surface_carrez_not_outliers.to_csv('Paris9e_Transactions_Carrez_not_outliers.csv', sep='/', index=False)

# %%
#export command to get the CSV file for Flats transaction (BATI)
db_surface_bati.to_csv('Paris9e_Transactions_Bati.csv', sep='/', index=False)

# %%
#export command to get the CSV file for Flats transaction (BATI_not_outliers)
db_surface_bati_not_outliers.to_csv('Paris9e_Transactions_Bati.csv', sep='/', index=False)

# %% [markdown]
# # Hypothesis Testing

# %%
db_hypothesis=db_general[(db_general['surface_carrez_total']!=0) & (db_general['surface_reelle_bati']!=0)]

# %%
from scipy.stats import ttest_ind

ttest_ind(db_hypothesis['surface_carrez_total'], db_hypothesis['surface_reelle_bati'])
# Out:
# Ttest_indResult(statistic=2.082491976426455, pvalue=0.0373202251174824)

# %% [markdown]
# Since pvalue is lower than 5%, we confirm that there is a difference and since statistics is above 0, we deduce that 'surface_carrez_total' has a higher surface than 'surface_reelle_bati'.

# %% [markdown]
# # Correlation

# %%
# We verify if there is a correlation between price and surface for bati
db_surface_bati_not_outliers[['valeur_fonciere','surface_reelle_bati']].corr()
# Out:
#                      valeur_fonciere  surface_reelle_bati
# valeur_fonciere             1.000000             0.939595
# surface_reelle_bati         0.939595             1.000000

# %% [markdown]
# As we can see, the price is highly positively correlated with the surface. The more the price is high, the more the surface will be high.

# %%
# We verify if there is a correlation between price and surface for carrez
db_surface_carrez_not_outliers[['valeur_fonciere','surface_carrez_total']].corr()
# Out:
#                       valeur_fonciere  surface_carrez_total
# valeur_fonciere              1.000000              0.918182
# surface_carrez_total         0.918182              1.000000

# %% [markdown]
# As we can see, the price is highly positively correlated with the surface.
